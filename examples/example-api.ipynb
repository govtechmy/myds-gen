# %% [markdown]
# Usage of myds_gen module

# %%
# import module
import requests as re
import json

# %%
API_ENDPOINT = "https://myds-gen-api.vercel.app/"

# %% [markdown]
# ## Generating a new component

# %%
component_description = (
    "a pricing component for Saas"  # provide a description of desired component
)
if re.post(F"{API_ENDPOINT}/api/py/validate-new-prompt?prompt={component_description}"):
    task_response = re.post(F"{API_ENDPOINT}/api/py/task_planning?prompt={component_description}")
    taskObject = task_response.json()

# %%
print(json.dumps(taskObject, indent=2))
# Out:
# {
#   "name": "PricingComponent_7d278b55-ab8b-4d69-9de4-ab792abecc5d",
#   "description": {
#     "user": "a pricing component for Saas",
#     "llm": "Displays different pricing plans for a SaaS product, highlighting features and benefits of each plan."
#   },
#   "icons": [
#     "checkicon"
#   ],
#   "components": [
#     {
#       "name": "Tabs",
#       "usage": "To organize different pricing plans into separate tabs for easy navigation."
#     },
#     {
#       "name": "Tag",
#       "usage": "To highlight the 'most popular' or 'recommended' plan."
#     },
#     {
#       "name": "Button",
#       "usage": "To provide a clear call-to-action for users to select a plan (e.g., 'Choose Plan', 'Get Started')."
#     },
#     {
#       "name": "Tooltip",
#       "usage": "To provide additional information or explanation about specific features in each plan."
#     },
#     {
#       "name": "Toggle",
#       "usage": "To allow users to switch between monthly and yearly billing cycles."
#     }
#   ]
# }

# %%
wireframe_response = re.post(F"{API_ENDPOINT}/api/py/wireframe_gen", json=taskObject)
wireframe = wireframe_response.json()
print(wireframe)
# Out:
# ```ascii
# +---------------------------------------------------------------------------------------+
# |                                 Pricing Component                                     |
# |---------------------------------------------------------------------------------------|
# |  [Tabs: Monthly | Yearly (Selected)]                                                   |
# |---------------------------------------------------------------------------------------|
# |                                                                                       |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |  |    Basic Plan       |   |   Standard Plan     |   |    Premium Plan     |          |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |  |  [Tag: Most Popular] |   |                     |   |                     |          |
# |  |                     |   |                     |   |                     |          |
# |  |   Price: $X/month   |   |   Price: $Y/month   |   |   Price: $Z/month   |          |
# |  |                     |   |                     |   |                     |          |
# |  |   [checkicon] Feature 1|   |   [checkicon] Feature 1|   |   [checkicon] Feature 1|          |
# |  |   [checkicon] Feature 2|   |   [checkicon] Feature 2|   |   [checkicon] Feature 2|          |
# |  |                     |   |   [checkicon] Feature 3|   |   [checkicon] Feature 3|          |
# |  |                     |   |                     |   |   [checkicon] Feature 4|          |
# |  |                     |   |                     |   |                     |          |
# |  | [Button: Choose Plan]|   | [Button: Choose Plan]|   | [Button: Choose Plan]|          |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |                                                                                       |
# +---------------------------------------------------------------------------------------+
# ```

# %%
taskObjectWithWireframe = {"task":taskObject, "wireframe":wireframe}
context_response = re.post(F"{API_ENDPOINT}/api/py/assemble_context", json=taskObjectWithWireframe)
generationContext = context_response.json()
print(generationContext)
# Out:
# # Wireframe Design of the component
#
# **Adhere fully to the wireframe, crafted by an expert UIUX Designer when building the component !**
#
# ```ascii
# +---------------------------------------------------------------------------------------+
# |                                 Pricing Component                                     |
# |---------------------------------------------------------------------------------------|
# |  [Tabs: Monthly | Yearly (Selected)]                                                   |
# |---------------------------------------------------------------------------------------|
# |                                                                                       |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |  |    Basic Plan       |   |   Standard Plan     |   |    Premium Plan     |          |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |  |  [Tag: Most Popular] |   |                     |   |                     |          |
# |  |                     |   |                     |   |                     |          |
# |  |   Price: $X/month   |   |   Price: $Y/month   |   |   Price: $Z/month   |          |
# |  |                     |   |                     |   |                     |          |
# |  |   [checkicon] Feature 1|   |   [checkicon] Feature 1|   |   [checkicon] Feature 1|          |
# |  |   [checkicon] Feature 2|   |   [checkicon] Feature 2|   |   [checkicon] Feature 2|          |
# |  |                     |   |   [checkicon] Feature 3|   |   [checkicon] Feature 3|          |
# |  |                     |   |                     |   |   [checkicon] Feature 4|          |
# |  |                     |   |                     |   |                     |          |
# |  | [Button: Choose Plan]|   | [Button: Choose Plan]|   | [Button: Choose Plan]|          |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |                                                                                       |
# +---------------------------------------------------------------------------------------+
# ```
#
# ---
# **Library components to be used while making the new React component.**
#
# # Suggested library component usages:
# - Tabs - To organize different pricing plans into separate tabs for easy navigation.
# - Tag - To highlight the 'most popular' or 'recommended' plan.
# - Button - To provide a clear call-to-action for users to select a plan (e.g., 'Choose Plan', 'Get Started').
# - Tooltip - To provide additional information or explanation about specific features in each plan.
# - Toggle - To allow users to switch between monthly and yearly billing cycles.
#
# # Suggested library component (0/11) : Tabs
# - Allows users to navigate between different views or content sections within the same context by clicking on tab.
# ## Tabs can be imported into the new component like this:
# ```tsx
# import {
#   Tabs,
#   TabsList,
#   TabsTrigger,
#   TabsContent,
#   TabsCounter,
# } from "@govtechmy/myds-react/tabs";
# ```
#
# ---
#
# ## examples of how `Tabs` can be used inside the new component:
# ```tsx
# export default () => (
#   <Tabs>
#     <TabsList>
#       <TabsTrigger />
#     </TabsList>
#     <TabsContent />
#   </Tabs>
# );
# ```
#
#
# ## full code examples of React components that use `Tabs` :
# ```tsx
# import {
#   Tabs,
#   TabsList,
#   TabsTrigger,
#   TabsContent,
#   TabsCounter,
# } from "@govtechmy/myds-react/tabs";
# export default function component() {
# 	return (import {
# 		    Tabs,
# 		    TabsContent,
# 		    TabsCounter,
# 		} from "@/components/myds";
#
# 		<Tabs
# 		    defaultValue="1"
# 		    size="small"
# 		    variant="line"
# 		>
# 		    <TabsList>
# 		        <TabsTrigger value="1">Novel</TabsTrigger>
# 		        <TabsTrigger value="2">Short Story</TabsTrigger>
# 		        <TabsTrigger value="3">Poetry</TabsTrigger>
# 		        <TabsTrigger value="4">Drama</TabsTrigger>
# 		    </TabsList>
# 		    <TabsContent value="1" className="py-6">
# 		         A novel is a long work of fiction that presents a complete story with
# 		         characters, plot, and setting. It typically encompasses various themes
# 		         such as love, family, life struggles, and societal challenges. Novels
# 		         allow readers to immerse themselves in new worlds through the author's
# 		         imagination.
# 		     </TabsContent>
#
# 		     <TabsContent value="2" className="py-6">
# 		         A short story is a brief work of fiction that can be read in one
# 		         sitting. Despite its concise format, it still contains engaging plots
# 		         and impactful characters. This compact format requires precise writing
# 		         to effectively deliver its message.
# 		     </TabsContent>
#
# 		     <TabsContent value="3" className="py-6">
# 		         Poetry is a creative form of writing that uses beautiful and rhythmic
# 		         language to convey feelings and ideas. Each line of poetry is carefully
# 		         chosen to create a deep impact on the reader, whether through rhyme,
# 		         metaphor, or symbolism.
# 		     </TabsContent>
#
# 		     <TabsContent value="4" className="py-6">
# 		         Drama is a work written for stage performance. It contains dialogue
# 		         between characters and clear stage directions. Drama can evoke various
# 		         emotions in the audience, from comedy to tragedy, while delivering
# 		         meaningful social messages.
# 		     </TabsContent>
# 		</Tabs>
#
# 		// for pill variant
# 		<Tabs
# 		    defaultValue="1"
# 		    size="small"
# 		    variant="pill"
# 		>
# 		    <TabsList>
# 		        <TabsTrigger value="1">Novel</TabsTrigger>
# 		        <TabsTrigger value="2">Short Story</TabsTrigger>
# 		        <TabsTrigger value="3">Poetry</TabsTrigger>
# 		        <TabsTrigger value="4">Drama</TabsTrigger>
# 		    </TabsList>
# 		    <TabsContent value="1" className="py-6">
# 		         A novel is a long work of fiction that presents a complete story with
# 		         characters, plot, and setting. It typically encompasses various themes
# 		         such as love, family, life struggles, and societal challenges. Novels
# 		         allow readers to immerse themselves in new worlds through the author's
# 		         imagination.
# 		     </TabsContent>
#
# 		     <TabsContent value="2" className="py-6">
# 		         A short story is a brief work of fiction that can be read in one
# 		         sitting. Despite its concise format, it still contains engaging plots
# 		         and impactful characters. This compact format requires precise writing
# 		         to effectively deliver its message.
# 		     </TabsContent>
#
# 		     <TabsContent value="3" className="py-6">
# 		         Poetry is a creative form of writing that uses beautiful and rhythmic
# 		         language to convey feelings and ideas. Each line of poetry is carefully
# 		         chosen to create a deep impact on the reader, whether through rhyme,
# 		         metaphor, or symbolism.
# 		     </TabsContent>
#
# 		     <TabsContent value="4" className="py-6">
# 		         Drama is a work written for stage performance. It contains dialogue
# 		         between characters and clear stage directions. Drama can evoke various
# 		         emotions in the audience, from comedy to tragedy, while delivering
# 		         meaningful social messages.
# 		     </TabsContent>
# 		</Tabs>
#
# 		// for enclosed variant
# 		<Tabs
# 		    defaultValue="1"
# 		    size="small"
# 		    variant="enclosed"
# 		>
# 		   <TabsContent value="1" className="py-6">
# 		     A novel is a long work of fiction that presents a complete story with
# 		     characters, plot, and setting. It typically encompasses various themes
# 		     such as love, family, life struggles, and societal challenges. Novels
# 		     allow readers to immerse themselves in new worlds through the author's
# 		     imagination.
# 		 </TabsContent>
#
# 		 <TabsContent value="2" className="py-6">
# 		     A short story is a brief work of fiction that can be read in one
# 		     sitting. Despite its concise format, it still contains engaging plots
# 		     and impactful characters. This compact format requires precise writing
# 		     to effectively deliver its message.
# 		 </TabsContent>
#
# 		 <TabsContent value="3" className="py-6">
# 		     Poetry is a creative form of writing that uses beautiful and rhythmic
# 		     language to convey feelings and ideas. Each line of poetry is carefully
# 		     chosen to create a deep impact on the reader, whether through rhyme,
# 		     metaphor, or symbolism.
# 		 </TabsContent>
#
# 		 <TabsContent value="4" className="py-6">
# 		     Drama is a work written for stage performance. It contains dialogue
# 		     between characters and clear stage directions. Drama can evoke various
# 		     emotions in the audience, from comedy to tragedy, while delivering
# 		     meaningful social messages.
# 		 </TabsContent>
# 		</Tabs>
# 	);
# }
# ```
#
# ```tsx
# import {
#   Tabs,
#   TabsList,
#   TabsTrigger,
#   TabsContent,
#   TabsCounter,
# } from "@govtechmy/myds-react/tabs";
# export default function component() {
# 	return (import {
# 		    Tabs,
# 		    TabsContent,
# 		    TabsCounter,
# 		} from "@/components/myds";
#
# 		<Tabs
# 		    defaultValue="1"
# 		    size="small"
# 		    variant="line"
# 		>
# 		    <TabsList>
# 		        <TabsTrigger value="1">Novel</TabsTrigger>
# 		        <TabsTrigger value="2">Short Story</TabsTrigger>
# 		        <TabsTrigger value="3">Poetry</TabsTrigger>
# 		        <TabsTrigger value="4">Drama</TabsTrigger>
# 		    </TabsList>
# 		    <TabsContent value="1" className="py-6">
# 		         A novel is a long work of fiction that presents a complete story with
# 		         characters, plot, and setting. It typically encompasses various themes
# 		         such as love, family, life struggles, and societal challenges. Novels
# 		         allow readers to immerse themselves in new worlds through the author's
# 		         imagination.
# 		     </TabsContent>
#
# 		     <TabsContent value="2" className="py-6">
# 		         A short story is a brief work of fiction that can be read in one
# 		         sitting. Despite its concise format, it still contains engaging plots
# 		         and impactful characters. This compact format requires precise writing
# 		         to effectively deliver its message.
# 		     </TabsContent>
#
# 		     <TabsContent value="3" className="py-6">
# 		         Poetry is a creative form of writing that uses beautiful and rhythmic
# 		         language to convey feelings and ideas. Each line of poetry is carefully
# 		         chosen to create a deep impact on the reader, whether through rhyme,
# 		         metaphor, or symbolism.
# 		     </TabsContent>
#
# 		     <TabsContent value="4" className="py-6">
# 		         Drama is a work written for stage performance. It contains dialogue
# 		         between characters and clear stage directions. Drama can evoke various
# 		         emotions in the audience, from comedy to tragedy, while delivering
# 		         meaningful social messages.
# 		     </TabsContent>
# 		</Tabs>
#
# 		<Tabs
# 		    defaultValue="1"
# 		    size="medium"
# 		    variant="line"
# 		>
# 		    <TabsList>
# 		        <TabsTrigger value="1">Novel</TabsTrigger>
# 		        <TabsTrigger value="2">Short Story</TabsTrigger>
# 		        <TabsTrigger value="3">Poetry</TabsTrigger>
# 		        <TabsTrigger value="4">Drama</TabsTrigger>
# 		    </TabsList>
# 		    <TabsContent value="1" className="py-6">
# 		         A novel is a long work of fiction that presents a complete story with
# 		         characters, plot, and setting. It typically encompasses various themes
# 		         such as love, family, life struggles, and societal challenges. Novels
# 		         allow readers to immerse themselves in new worlds through the author's
# 		         imagination.
# 		     </TabsContent>
#
# 		     <TabsContent value="2" className="py-6">
# 		         A short story is a brief work of fiction that can be read in one
# 		         sitting. Despite its concise format, it still contains engaging plots
# 		         and impactful characters. This compact format requires precise writing
# 		         to effectively deliver its message.
# 		     </TabsContent>
#
# 		     <TabsContent value="3" className="py-6">
# 		         Poetry is a creative form of writing that uses beautiful and rhythmic
# 		         language to convey feelings and ideas. Each line of poetry is carefully
# 		         chosen to create a deep impact on the reader, whether through rhyme,
# 		         metaphor, or symbolism.
# 		     </TabsContent>
#
# 		     <TabsContent value="4" className="py-6">
# 		         Drama is a work written for stage performance. It contains dialogue
# 		         between characters and clear stage directions. Drama can evoke various
# 		         emotions in the audience, from comedy to tragedy, while delivering
# 		         meaningful social messages.
# 		     </TabsContent>
# 		</Tabs>
#
# 		// for pill variant
# 		<Tabs
# 		    defaultValue="1"
# 		    size="small"
# 		    variant="pill"
# 		>
# 		    <TabsList>
# 		        <TabsTrigger value="1">Novel</TabsTrigger>
# 		        <TabsTrigger value="2">Short Story</TabsTrigger>
# 		        <TabsTrigger value="3">Poetry</TabsTrigger>
# 		        <TabsTrigger value="4">Drama</TabsTrigger>
# 		    </TabsList>
# 		    <TabsContent value="1" className="py-6">
# 		         A novel is a long work of fiction that presents a complete story with
# 		         characters, plot, and setting. It typically encompasses various themes
# 		         such as love, family, life struggles, and societal challenges. Novels
# 		         allow readers to immerse themselves in new worlds through the author's
# 		         imagination.
# 		     </TabsContent>
#
# 		     <TabsContent value="2" className="py-6">
# 		         A short story is a brief work of fiction that can be read in one
# 		         sitting. Despite its concise format, it still contains engaging plots
# 		         and impactful characters. This compact format requires precise writing
# 		         to effectively deliver its message.
# 		     </TabsContent>
#
# 		     <TabsContent value="3" className="py-6">
# 		         Poetry is a creative form of writing that uses beautiful and rhythmic
# 		         language to convey feelings and ideas. Each line of poetry is carefully
# 		         chosen to create a deep impact on the reader, whether through rhyme,
# 		         metaphor, or symbolism.
# 		     </TabsContent>
#
# 		     <TabsContent value="4" className="py-6">
# 		         Drama is a work written for stage performance. It contains dialogue
# 		         between characters and clear stage directions. Drama can evoke various
# 		         emotions in the audience, from comedy to tragedy, while delivering
# 		         meaningful social messages.
# 		     </TabsContent>
# 		</Tabs>
#
# 		<Tabs
# 		    defaultValue="1"
# 		    size="medium"
# 		    variant="pill"
# 		>
# 		    <TabsList>
# 		        <TabsTrigger value="1">Novel</TabsTrigger>
# 		        <TabsTrigger value="2">Short Story</TabsTrigger>
# 		        <TabsTrigger value="3">Poetry</TabsTrigger>
# 		        <TabsTrigger value="4">Drama</TabsTrigger>
# 		    </TabsList>
# 		    <TabsContent value="1" className="py-6">
# 		         A novel is a long work of fiction that presents a complete story with
# 		         characters, plot, and setting. It typically encompasses various themes
# 		         such as love, family, life struggles, and societal challenges. Novels
# 		         allow readers to immerse themselves in new worlds through the author's
# 		         imagination.
# 		     </TabsContent>
#
# 		     <TabsContent value="2" className="py-6">
# 		         A short story is a brief work of fiction that can be read in one
# 		         sitting. Despite its concise format, it still contains engaging plots
# 		         and impactful characters. This compact format requires precise writing
# 		         to effectively deliver its message.
# 		     </TabsContent>
#
# 		     <TabsContent value="3" className="py-6">
# 		         Poetry is a creative form of writing that uses beautiful and rhythmic
# 		         language to convey feelings and ideas. Each line of poetry is carefully
# 		         chosen to create a deep impact on the reader, whether through rhyme,
# 		         metaphor, or symbolism.
# 		     </TabsContent>
#
# 		     <TabsContent value="4" className="py-6">
# 		         Drama is a work written for stage performance. It contains dialogue
# 		         between characters and clear stage directions. Drama can evoke various
# 		         emotions in the audience, from comedy to tragedy, while delivering
# 		         meaningful social messages.
# 		     </TabsContent>
# 		</Tabs>
#
# 		// for enclosed variant
# 		<Tabs
# 		    defaultValue="1"
# 		    size="small"
# 		    variant="enclosed"
# 		>
# 		    <TabsList>
# 		        <TabsTrigger value="1">Novel</TabsTrigger>
# 		        <TabsTrigger value="2">Short Story</TabsTrigger>
# 		        <TabsTrigger value="3">Poetry</TabsTrigger>
# 		        <TabsTrigger value="4">Drama</TabsTrigger>
# 		    </TabsList>
# 		    <TabsContent value="1" className="py-6">
# 		         A novel is a long work of fiction that presents a complete story with
# 		         characters, plot, and setting. It typically encompasses various themes
# 		         such as love, family, life struggles, and societal challenges. Novels
# 		         allow readers to immerse themselves in new worlds through the author's
# 		         imagination.
# 		     </TabsContent>
#
# 		     <TabsContent value="2" className="py-6">
# 		         A short story is a brief work of fiction that can be read in one
# 		         sitting. Despite its concise format, it still contains engaging plots
# 		         and impactful characters. This compact format requires precise writing
# 		         to effectively deliver its message.
# 		     </TabsContent>
#
# 		     <TabsContent value="3" className="py-6">
# 		         Poetry is a creative form of writing that uses beautiful and rhythmic
# 		         language to convey feelings and ideas. Each line of poetry is carefully
# 		         chosen to create a deep impact on the reader, whether through rhyme,
# 		         metaphor, or symbolism.
# 		     </TabsContent>
#
# 		     <TabsContent value="4" className="py-6">
# 		         Drama is a work written for stage performance. It contains dialogue
# 		         between characters and clear stage directions. Drama can evoke various
# 		         emotions in the audience, from comedy to tragedy, while delivering
# 		         meaningful social messages.
# 		     </TabsContent>
# 		</Tabs>
#
# 		<Tabs
# 		    defaultValue="1"
# 		    size="medium"
# 		    variant="enclosed"
# 		>
# 		    <TabsList>
# 		        <TabsTrigger value="1">Novel</TabsTrigger>
# 		        <TabsTrigger value="2">Short Story</TabsTrigger>
# 		        <TabsTrigger value="3">Poetry</TabsTrigger>
# 		        <TabsTrigger value="4">Drama</TabsTrigger>
# 		    </TabsList>
# 		    <TabsContent value="1" className="py-6">
# 		         A novel is a long work of fiction that presents a complete story with
# 		         characters, plot, and setting. It typically encompasses various themes
# 		         such as love, family, life struggles, and societal challenges. Novels
# 		         allow readers to immerse themselves in new worlds through the author's
# 		         imagination.
# 		     </TabsContent>
#
# 		     <TabsContent value="2" className="py-6">
# 		         A short story is a brief work of fiction that can be read in one
# 		         sitting. Despite its concise format, it still contains engaging plots
# 		         and impactful characters. This compact format requires precise writing
# 		         to effectively deliver its message.
# 		     </TabsContent>
#
# 		     <TabsContent value="3" className="py-6">
# 		         Poetry is a creative form of writing that uses beautiful and rhythmic
# 		         language to convey feelings and ideas. Each line of poetry is carefully
# 		         chosen to create a deep impact on the reader, whether through rhyme,
# 		         metaphor, or symbolism.
# 		     </TabsContent>
#
# 		     <TabsContent value="4" className="py-6">
# 		         Drama is a work written for stage performance. It contains dialogue
# 		         between characters and clear stage directions. Drama can evoke various
# 		         emotions in the audience, from comedy to tragedy, while delivering
# 		         meaningful social messages.
# 		     </TabsContent>
# 		</Tabs>
# 	);
# }
# ```
#
# ```tsx
# import {
#   Tabs,
#   TabsList,
#   TabsTrigger,
#   TabsContent,
#   TabsCounter,
# } from "@govtechmy/myds-react/tabs";
# export default function component() {
# 	return (import {
# 		    Tabs,
# 		    TabsContent,
# 		    TabsCounter,
# 		} from "@/components/myds";
#
# 		<TabsList>
# 		    <TabsTrigger value="1">
# 		        <TabsIcon>
# 		            <ArrowForwardIcon/>
# 		        </TabsIcon>
# 		        Novel
# 		    </TabsTrigger>
# 		    <TabsTrigger value="2">
# 		        <TabsIcon>
# 		            <ArrowForwardIcon/>
# 		        </TabsIcon>
# 		        Short Story
# 		    </TabsTrigger>
# 		    <TabsTrigger value="3">
# 		        <TabsIcon>
# 		            <ArrowForwardIcon/>
# 		        </TabsIcon>
# 		        Poem
# 		    </TabsTrigger>
# 		    <TabsTrigger value="4">
# 		        <TabsIcon>
# 		            <ArrowForwardIcon/>
# 		        </TabsIcon>
# 		        Drama
# 		    </TabsTrigger>
# 		</TabsList>
# 		<TabsContent value="1" className="py-6">
# 		    A novel is a long work of fiction that presents a complete story with
# 		    characters, plot, and setting. It typically encompasses various themes
# 		    such as love, family, life struggles, and societal challenges. Novels
# 		    allow readers to immerse themselves in new worlds through the author's
# 		    imagination.
# 		</TabsContent>
# 		<TabsContent value="2" className="py-6">
# 		    A short story is a brief work of fiction that can be read in one
# 		    sitting. Despite its concise format, it still contains engaging plots
# 		    and impactful characters. This compact format requires precise writing
# 		    to effectively deliver its message.
# 		</TabsContent>
# 		<TabsContent value="3" className="py-6">
# 		    Poetry is a creative form of writing that uses beautiful and rhythmic
# 		    language to convey feelings and ideas. Each line of poetry is carefully
# 		    chosen to create a deep impact on the reader, whether through rhyme,
# 		    metaphor, or symbolism.
# 		</TabsContent>
# 		<TabsContent value="4" className="py-6">
# 		    Drama is a work written for stage performance. It contains dialogue
# 		    between characters and clear stage directions. Drama can evoke various
# 		    emotions in the audience, from comedy to tragedy, while delivering
# 		    meaningful social messages.
# 		</TabsContent>
# 	);
# }
# ```
#
# ```tsx
# import {
#   Tabs,
#   TabsList,
#   TabsTrigger,
#   TabsContent,
#   TabsCounter,
# } from "@govtechmy/myds-react/tabs";
# export default function component() {
# 	return (import {
# 		    Tabs,
# 		    TabsContent,
# 		    TabsCounter,
# 		} from "@/components/myds";
#
# 		<Tabs
# 		    defaultValue="1"
# 		    size="small"
# 		    variant="line"
# 		>
# 		    <TabsList>
# 		        <TabsTrigger value="1">
# 		            Novel
# 		            <TabsCounter>1</TabsCounter>
# 		        </TabsTrigger>
# 		        <TabsTrigger value="2">
# 		            Short Story
# 		            <TabsCounter>1</TabsCounter>
# 		        </TabsTrigger>
# 		        <TabsTrigger value="3">
# 		            Short Story
# 		            <TabsCounter>1</TabsCounter>
# 		        </TabsTrigger>
# 		        <TabsTrigger value="4">
# 		            Drama
# 		            <TabsCounter>1</TabsCounter>
# 		        </TabsTrigger>
# 		    </TabsList>
# 		    <TabsContent value="1" className="py-6">
# 		        A novel is a long work of fiction that presents a complete story with
# 		        characters, plot, and setting. It typically encompasses various themes
# 		        such as love, family, life struggles, and societal challenges. Novels
# 		        allow readers to immerse themselves in new worlds through the author's
# 		        imagination.
# 		    </TabsContent>
#
# 		    <TabsContent value="2" className="py-6">
# 		        A short story is a brief work of fiction that can be read in one
# 		        sitting. Despite its concise format, it still contains engaging plots
# 		        and impactful characters. This compact format requires precise writing
# 		        to effectively deliver its message.
# 		    </TabsContent>
#
# 		    <TabsContent value="3" className="py-6">
# 		        Poetry is a creative form of writing that uses beautiful and rhythmic
# 		        language to convey feelings and ideas. Each line of poetry is carefully
# 		        chosen to create a deep impact on the reader, whether through rhyme,
# 		        metaphor, or symbolism.
# 		    </TabsContent>
#
# 		    <TabsContent value="4" className="py-6">
# 		        Drama is a work written for stage performance. It contains dialogue
# 		        between characters and clear stage directions. Drama can evoke various
# 		        emotions in the audience, from comedy to tragedy, while delivering
# 		        meaningful social messages.
# 		    </TabsContent>
# 		</Tabs>
# 	);
# }
# ```
#
# ## API reference for `Tabs` :
#
# ### Tabs
#
# |         | description              | type   | default   | typeDescription        |
# |---------|--------------------------|--------|-----------|------------------------|
# | variant | Style variant of the tab | enum   | line      | pill | enclosed | line |
# | size    | Sizes of the tab         | enum   | small     | small | medium         |
#
# ### TabsList
#
# |       | description          | type   | default   | typeDescription   |
# |-------|----------------------|--------|-----------|-------------------|
# | width | Width of the TabList | enum   | fit       | full | fit        |
#
# # Suggested library component (1/11) : Data Table
# - Organizes information into rows and columns for easy readability. It accommodates various data types, including text, numbers, codes, call-to-action and links, enabling efficient presentation and comparison.
# ## Data Table can be imported into the new component like this:
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# ```
#
# ---
#
# ## examples of how `Data Table` can be used inside the new component:
# ```tsx
# export default () => <DataTable />;
# ```
#
#
# ## full code examples of React components that use `Data Table` :
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (<DataTable
# 		  data={[
# 		    {
# 		      age: 25,
# 		      id: 1,
# 		      name: "John Doe",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 30,
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      position: "Product Manager",
# 		    },
# 		    {
# 		      age: 22,
# 		      id: 3,
# 		      name: "Alice",
# 		      position: "Designer",
# 		    },
# 		    {
# 		      age: 35,
# 		      id: 4,
# 		      name: "Bob 'With A Very Long Middle Name' Smith",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 28,
# 		      id: 5,
# 		      name: "Charlie",
# 		      position: "Data Scientist",
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      accessorKey: "name",
# 		      header: "Name",
# 		      id: "name",
# 		      meta: {
# 		        expandable: true,
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "age",
# 		      header: "Age",
# 		      id: "age",
# 		      meta: {
# 		        expandable: false,
# 		        tooltip: "Age of the employee",
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "position",
# 		      header: "Position",
# 		      id: "position",
# 		      meta: {
# 		        expandable: true,
# 		        sortable: true,
# 		        tooltip: "Position of the employee",
# 		      },
# 		    },
# 		    {
# 		      cell: () => {
# 		        return (
# 		            <Tag variant="success" size={"small"} mode="pill">
# 		            Success
# 		            </Tag>
# 		        );
# 		      },
# 		      header: "Status",
# 		      id: "status",
# 		    },
# 		    {
# 		      cell: () => {
# 		        return <Button variant="default-outline">Edit</Button>;
# 		      },
# 		      header: "Action",
# 		      id: "action",
# 		    },
# 		  ]}
# 		/>
# 	);
# }
# ```
#
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (<DataTable
# 		  data={[
# 		    {
# 		      age: 25,
# 		      id: 1,
# 		      name: "John Doe",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 30,
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      position: "Product Manager",
# 		    },
# 		    {
# 		      age: 22,
# 		      id: 3,
# 		      name: "Alice",
# 		      position: "Designer",
# 		    },
# 		    {
# 		      age: 35,
# 		      id: 4,
# 		      name: "Bob 'With A Very Long Middle Name' Smith",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 28,
# 		      id: 5,
# 		      name: "Charlie",
# 		      position: "Data Scientist",
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      accessorKey: "name",
# 		      header: "Name",
# 		      id: "name",
# 		      meta: {
# 		        expandable: true,
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "age",
# 		      header: "Age",
# 		      id: "age",
# 		      meta: {
# 		        expandable: false,
# 		        tooltip: "Age of the employee",
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "position",
# 		      header: "Position",
# 		      id: "position",
# 		      meta: {
# 		        expandable: true,
# 		        sortable: true,
# 		        tooltip: "Position of the employee",
# 		      },
# 		    },
# 		    {
# 		      cell: () => {
# 		        return (
# 		            <Tag variant="success" size={"small"} mode="pill">
# 		            Success
# 		            </Tag>
# 		        );
# 		      },
# 		      header: "Status",
# 		      id: "status",
# 		    },
# 		    {
# 		      cell: () => {
# 		        return <Button variant="default-outline">Edit</Button>;
# 		      },
# 		      header: "Action",
# 		      id: "action",
# 		    },
# 		  ]}
# 		/>
# 	);
# }
# ```
#
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (<DataTable
# 		  data={[
# 		    {
# 		      age: 25,
# 		      id: 1,
# 		      name: "John Doe",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 30,
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      position: "Product Manager",
# 		    },
# 		    {
# 		      age: 22,
# 		      id: 3,
# 		      name: "Alice",
# 		      position: "Designer",
# 		    },
# 		    {
# 		      age: 35,
# 		      id: 4,
# 		      name: "Bob 'With A Very Long Middle Name' Smith",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 28,
# 		      id: 5,
# 		      name: "Charlie",
# 		      position: "Data Scientist",
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      accessorKey: "name",
# 		      header: "Name",
# 		      id: "name",
# 		      meta: {
# 		        expandable: true,
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "age",
# 		      header: "Age",
# 		      id: "age",
# 		      meta: {
# 		        expandable: false,
# 		        tooltip: "Age of the employee",
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "position",
# 		      header: "Position",
# 		      id: "position",
# 		      meta: {
# 		        expandable: true,
# 		        sortable: true,
# 		        tooltip: "Position of the employee",
# 		      },
# 		    },
# 		    {
# 		      cell: () => {
# 		        return (
# 		            <Tag variant="success" size={"small"} mode="pill">
# 		            Success
# 		            </Tag>
# 		        );
# 		      },
# 		      header: "Status",
# 		      id: "status",
# 		    },
# 		    {
# 		      cell: () => {
# 		        return <Button variant="default-outline">Edit</Button>;
# 		      },
# 		      header: "Action",
# 		      id: "action",
# 		    },
# 		  ]}
# 		/>
# 	);
# }
# ```
#
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (<DataTable
# 		  data={[
# 		    {
# 		      age: 25,
# 		      id: 1,
# 		      name: "John Doe",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 30,
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      position: "Product Manager",
# 		    },
# 		    {
# 		      age: 22,
# 		      id: 3,
# 		      name: "Alice",
# 		      position: "Designer",
# 		    },
# 		    {
# 		      age: 35,
# 		      id: 4,
# 		      name: "Bob 'With A Very Long Middle Name' Smith",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 28,
# 		      id: 5,
# 		      name: "Charlie",
# 		      position: "Data Scientist",
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      accessorKey: "name",
# 		      header: "Name",
# 		      id: "name",
# 		      meta: {
# 		        expandable: true,
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "age",
# 		      header: "Age",
# 		      id: "age",
# 		      meta: {
# 		        expandable: false,
# 		        tooltip: "Age of the employee",
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "position",
# 		      header: "Position",
# 		      id: "position",
# 		      meta: {
# 		        expandable: true,
# 		        sortable: true,
# 		        tooltip: "Position of the employee",
# 		      },
# 		    },
# 		    {
# 		      cell: () => {
# 		        return (
# 		            <Tag variant="success" size={"small"} mode="pill">
# 		            Success
# 		            </Tag>
# 		        );
# 		      },
# 		      header: "Status",
# 		      id: "status",
# 		    },
# 		    {
# 		      cell: () => {
# 		        return <Button variant="default-outline">Edit</Button>;
# 		      },
# 		      header: "Action",
# 		      id: "action",
# 		    },
# 		  ]}
# 		/>
# 	);
# }
# ```
#
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (<DataTable
# 		  loading
# 		  data={[
# 		    {
# 		      age: 25,
# 		      id: 1,
# 		      name: "John Doe",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 30,
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      position: "Product Manager",
# 		    },
# 		    {
# 		      age: 22,
# 		      id: 3,
# 		      name: "Alice",
# 		      position: "Designer",
# 		    },
# 		    {
# 		      age: 35,
# 		      id: 4,
# 		      name: "Bob 'With A Very Long Middle Name' Smith",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 28,
# 		      id: 5,
# 		      name: "Charlie",
# 		      position: "Data Scientist",
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      accessorKey: "name",
# 		      header: "Name",
# 		      id: "name",
# 		      meta: {
# 		        expandable: true,
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "age",
# 		      header: "Age",
# 		      id: "age",
# 		      meta: {
# 		        expandable: false,
# 		        tooltip: "Age of the employee",
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "position",
# 		      header: "Position",
# 		      id: "position",
# 		      meta: {
# 		        expandable: true,
# 		        sortable: true,
# 		        tooltip: "Position of the employee",
# 		      },
# 		    },
# 		    {
# 		      cell: () => {
# 		        return (
# 		            <Tag variant="success" size={"small"} mode="pill">
# 		            Success
# 		            </Tag>
# 		        );
# 		      },
# 		      header: "Status",
# 		      id: "status",
# 		    },
# 		    {
# 		      cell: () => {
# 		        return <Button variant="default-outline">Edit</Button>;
# 		      },
# 		      header: "Action",
# 		      id: "action",
# 		    },
# 		  ]}
# 		/>
# 	);
# }
# ```
#
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (<DataTable
# 		  data={[]}
# 		  columns={[
# 		    {
# 		      accessorKey: "name",
# 		      header: "Name",
# 		      id: "name",
# 		      meta: {
# 		        expandable: true,
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "age",
# 		      header: "Age",
# 		      id: "age",
# 		      meta: {
# 		        expandable: false,
# 		        tooltip: "Age of the employee",
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "position",
# 		      header: "Position",
# 		      id: "position",
# 		      meta: {
# 		        expandable: true,
# 		        sortable: true,
# 		        tooltip: "Position of the employee",
# 		      },
# 		    },
# 		    {
# 		      cell: () => {
# 		        return (
# 		            <Tag variant="success" size={"small"} mode="pill">
# 		            Success
# 		            </Tag>
# 		        );
# 		      },
# 		      header: "Status",
# 		      id: "status",
# 		    },
# 		    {
# 		      cell: () => {
# 		        return <Button variant="default-outline">Edit</Button>;
# 		      },
# 		      header: "Action",
# 		      id: "action",
# 		    },
# 		  ]}
# 		/>
# 	);
# }
# ```
#
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (// Checkbox Selection
# 		<DataTable
# 		  data={[
# 		    {
# 		      age: 25,
# 		      id: 1,
# 		      name: "John Doe",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 30,
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      position: "Product Manager",
# 		    },
# 		    {
# 		      age: 22,
# 		      id: 3,
# 		      name: "Alice",
# 		      position: "Designer",
# 		    },
# 		    {
# 		      age: 35,
# 		      id: 4,
# 		      name: "Bob 'With A Very Long Middle Name' Smith",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 28,
# 		      id: 5,
# 		      name: "Charlie",
# 		      position: "Data Scientist",
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      accessorKey: "name",
# 		      header: "Name",
# 		      id: "name",
# 		      meta: {
# 		        expandable: true,
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "age",
# 		      header: "Age",
# 		      id: "age",
# 		      meta: {
# 		        expandable: false,
# 		        tooltip: "Age of the employee",
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "position",
# 		      header: "Position",
# 		      id: "position",
# 		      meta: {
# 		        expandable: true,
# 		        sortable: true,
# 		        tooltip: "Position of the employee",
# 		      },
# 		    },
# 		    {
# 		      cell: () => {
# 		        return (
# 		            <Tag variant="success" size={"small"} mode="pill">
# 		            Success
# 		            </Tag>
# 		        );
# 		      },
# 		      header: "Status",
# 		      id: "status",
# 		    },
# 		    {
# 		      cell: () => {
# 		        return <Button variant="default-outline">Edit</Button>;
# 		      },
# 		      header: "Action",
# 		      id: "action",
# 		    },
# 		  ]}
# 		  selection={
# 		    {
# 		      mode: "checkbox",
# 		      onSelectionChange: (id: string) => {
# 		        console.log("Selected Rows: ", id);
# 		      },
# 		      rowId: "id",
# 		    }
# 		  }
# 		/>
#
# 		// Radio Selection
# 		<DataTable
# 		  data={[
# 		    {
# 		      age: 25,
# 		      id: 1,
# 		      name: "John Doe",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 30,
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      position: "Product Manager",
# 		    },
# 		    {
# 		      age: 22,
# 		      id: 3,
# 		      name: "Alice",
# 		      position: "Designer",
# 		    },
# 		    {
# 		      age: 35,
# 		      id: 4,
# 		      name: "Bob 'With A Very Long Middle Name' Smith",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 28,
# 		      id: 5,
# 		      name: "Charlie",
# 		      position: "Data Scientist",
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      accessorKey: "name",
# 		      header: "Name",
# 		      id: "name",
# 		      meta: {
# 		        expandable: true,
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "age",
# 		      header: "Age",
# 		      id: "age",
# 		      meta: {
# 		        expandable: false,
# 		        tooltip: "Age of the employee",
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "position",
# 		      header: "Position",
# 		      id: "position",
# 		      meta: {
# 		        expandable: true,
# 		        sortable: true,
# 		        tooltip: "Position of the employee",
# 		      },
# 		    },
# 		    {
# 		      cell: () => {
# 		        return (
# 		            <Tag variant="success" size={"small"} mode="pill">
# 		            Success
# 		            </Tag>
# 		        );
# 		      },
# 		      header: "Status",
# 		      id: "status",
# 		    },
# 		    {
# 		      cell: () => {
# 		        return <Button variant="default-outline">Edit</Button>;
# 		      },
# 		      header: "Action",
# 		      id: "action",
# 		    },
# 		  ]}
# 		  selection={
# 		    {
# 		      mode: "radio",
# 		      onSelectionChange: (id: string) => {
# 		        console.log("Selected Rows: ", id);
# 		      },
# 		      rowId: "id",
# 		    }
# 		  }
# 		/>
# 	);
# }
# ```
#
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (<DataTable
# 		  data={[
# 		    {
# 		      age: 25,
# 		      id: 1,
# 		      name: "John Doe",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 30,
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      position: "Product Manager",
# 		    },
# 		    {
# 		      age: 22,
# 		      id: 3,
# 		      name: "Alice",
# 		      position: "Designer",
# 		    },
# 		    {
# 		      age: 35,
# 		      id: 4,
# 		      name: "Bob 'With A Very Long Middle Name' Smith",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 28,
# 		      id: 5,
# 		      name: "Charlie",
# 		      position: "Data Scientist",
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      id: "employee",
# 		      header: "Employee",
# 		      columns: [
# 		        {
# 		          id: "name",
# 		          header: "Name",
# 		          accessorKey: "name",
# 		          size: 180,
# 		          meta: {
# 		            expandable: true,
# 		          },
# 		        },
# 		        {
# 		          id: "age",
# 		          header: "Age",
# 		          accessorKey: "age",
#
# 		          meta: {
# 		            expandable: false,
# 		          },
# 		        },
# 		        {
# 		          id: "position",
# 		          header: "Position",
# 		          accessorKey: "position",
# 		          meta: {
# 		            expandable: true,
# 		          },
# 		        },
# 		      ],
# 		    },
# 		    {
# 		      id: "status",
# 		      header: "Application",
# 		      columns: [
# 		        {
# 		          id: "status",
# 		          header: "Status",
# 		          cell: () => {
# 		            return (
# 		              <Tag variant="success" size={"small"} mode="pill">
# 		                Success
# 		              </Tag>
# 		            );
# 		          },
# 		        },
# 		        {
# 		          id: "action",
# 		          header: "Action",
# 		          cell: () => {
# 		            return <Button variant="default-outline">Edit</Button>;
# 		          },
# 		        },
# 		      ],
# 		    }
# 		  ]
# 		  }
# 		/>
# 	);
# }
# ```
#
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (<DataTable
# 		  className="max-h-[300px]"
# 		  data={[
# 		    {
# 		      age: 25,
# 		      id: 1,
# 		      name: "John Doe",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 30,
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      position: "Product Manager",
# 		    },
# 		    {
# 		      age: 22,
# 		      id: 3,
# 		      name: "Alice",
# 		      position: "Designer",
# 		    },
# 		    {
# 		      age: 35,
# 		      id: 4,
# 		      name: "Bob 'With A Very Long Middle Name' Smith",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 28,
# 		      id: 5,
# 		      name: "Charlie",
# 		      position: "Data Scientist",
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      id: "employee",
# 		      header: "Employee",
# 		      columns: [
# 		        {
# 		          id: "name",
# 		          header: "Name",
# 		          accessorKey: "name",
# 		          size: 180,
# 		          meta: {
# 		            expandable: true,
# 		          },
# 		        },
# 		        {
# 		          id: "age",
# 		          header: "Age",
# 		          accessorKey: "age",
#
# 		          meta: {
# 		            expandable: false,
# 		          },
# 		        },
# 		        {
# 		          id: "position",
# 		          header: "Position",
# 		          accessorKey: "position",
# 		          meta: {
# 		            expandable: true,
# 		          },
# 		        },
# 		      ],
# 		    },
# 		    {
# 		      id: "status",
# 		      header: "Application",
# 		      columns: [
# 		        {
# 		          id: "status",
# 		          header: "Status",
# 		          cell: () => {
# 		            return (
# 		              <Tag variant="success" size={"small"} mode="pill">
# 		                Success
# 		              </Tag>
# 		            );
# 		          },
# 		        },
# 		        {
# 		          id: "action",
# 		          header: "Action",
# 		          cell: () => {
# 		            return <Button variant="default-outline">Edit</Button>;
# 		          },
# 		        },
# 		      ],
# 		    }
# 		  ]
# 		  }
# 		/>
# 	);
# }
# ```
#
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (<DataTable
# 		  data={[
# 		    {
# 		      id: 1,
# 		      name: "John Doe",
# 		      age: 25,
# 		      position: "Software Engineer",
# 		      children: [
# 		        {
# 		          id: 11,
# 		          name: "John Doe Jr.",
# 		          age: 5,
# 		          position: "Software Engineer",
# 		          children: [
# 		            {
# 		              id: 111,
# 		              name: "John Doe-raemon",
# 		              age: 5,
# 		              position: "Software Engineer",
# 		            },
# 		            {
# 		              id: 112,
# 		              name: "John 'Penat' Doe",
# 		              age: 5,
# 		              position: "Software Engineer",
# 		            },
# 		          ],
# 		        },
# 		        {
# 		          id: 12,
# 		          name: "John Doe Jr.",
# 		          age: 5,
# 		          position: "Software Engineer",
# 		        },
# 		      ],
# 		    },
# 		    {
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      age: 30,
# 		      position: "Product Manager",
# 		      children: [
# 		        {
# 		          id: 21,
# 		          name: "Jane Doe Jr. 1",
# 		          age: 5,
# 		          position: "Software Engineer",
# 		        },
# 		        {
# 		          id: 22,
# 		          name: "Jane Doe Jr. 2",
# 		          age: 5,
# 		          position: "Software Engineer",
# 		        },
# 		      ],
# 		    },
# 		    {
# 		      id: 3,
# 		      name: "Alice",
# 		      age: 22,
# 		      position: "Designer",
# 		      children: [
# 		        {
# 		          id: 31,
# 		          name: "Alice Jr. 1",
# 		          age: 5,
# 		          position: "Software Engineer",
# 		        },
# 		        {
# 		          id: 32,
# 		          name: "Alice Jr. 2",
# 		          age: 5,
# 		          position: "Software Engineer",
# 		        },
# 		      ],
# 		    },
# 		    {
# 		      id: 4,
# 		      name: "Bob",
# 		      age: 35,
# 		      position: "Software Engineer",
# 		      children: [
# 		        {
# 		          id: 41,
# 		          name: "Bob Jr. 1",
# 		          age: 5,
# 		          position: "Software Engineer",
# 		        },
# 		        {
# 		          id: 42,
# 		          name: "Bob Jr. 2",
# 		          age: 5,
# 		          position: "Software Engineer",
# 		        },
# 		      ],
# 		    },
# 		    {
# 		      id: 5,
# 		      name: "Charlie",
# 		      age: 28,
# 		      position: "Data Scientist",
# 		      children: [
# 		        {
# 		          id: 51,
# 		          name: "Charlie Jr. 1",
# 		          age: 5,
# 		          position: "Software Engineer",
# 		        },
# 		        {
# 		          id: 52,
# 		          name: "Charlie Jr. 2",
# 		          age: 5,
# 		          position: "Software Engineer",
# 		        },
# 		      ],
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      accessorKey: "name",
# 		      header: "Name",
# 		      id: "name",
# 		      meta: {
# 		        expandable: true,
# 		      },
# 		      cell: Cell.Expand
# 		    },
# 		    {
# 		      accessorKey: "age",
# 		      header: "Age",
# 		      id: "age",
# 		      meta: {
# 		        expandable: false,
# 		        tooltip: "Age of the employee",
# 		      },
# 		    },
# 		    {
# 		      accessorKey: "position",
# 		      header: "Position",
# 		      id: "position",
# 		      meta: {
# 		        expandable: true,
# 		        sortable: true,
# 		        tooltip: "Position of the employee",
# 		      },
# 		    },
# 		    {
# 		      cell: () => {
# 		        return (
# 		            <Tag variant="success" size={"small"} mode="pill">
# 		            Success
# 		            </Tag>
# 		        );
# 		      },
# 		      header: "Status",
# 		      id: "status",
# 		    },
# 		    {
# 		      cell: () => {
# 		        return <Button variant="default-outline">Edit</Button>;
# 		      },
# 		      header: "Action",
# 		      id: "action",
# 		    }
# 		  ]}
# 		  nest={{ id_by: "children" }}
# 		/>
# 	);
# }
# ```
#
# ```tsx
# import { DataTable } from "@govtechmy/myds-react/data-table";
# export default function component() {
# 	return (<DataTable
# 		  data={[
# 		    {
# 		      age: 25,
# 		      id: 1,
# 		      name: "John Doe",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 30,
# 		      id: 2,
# 		      name: "Jane Doe",
# 		      position: "Product Manager",
# 		    },
# 		    {
# 		      age: 22,
# 		      id: 3,
# 		      name: "Alice",
# 		      position: "Designer",
# 		    },
# 		    {
# 		      age: 35,
# 		      id: 4,
# 		      name: "Bob 'With A Very Long Middle Name' Smith",
# 		      position: "Software Engineer",
# 		    },
# 		    {
# 		      age: 28,
# 		      id: 5,
# 		      name: "Charlie",
# 		      position: "Data Scientist",
# 		    },
# 		  ]}
# 		  columns={[
# 		    {
# 		      accessorKey: "name",
# 		      header: "Name",
# 		      id: "name",
# 		      meta: {
# 		        expandable: true,
# 		      },
# 		    },
# 		    {
# ...
# 		        <DropdownItem variant="danger">
# 		            <DropdownItemIcon>
# 		                <LogoutIcon />
# 		            </DropdownItemIcon>
# 		            Logout
# 		        </DropdownItem>
# 		    </DropdownContent>
# 		</Dropdown>
# 	);
# }
# ```
#
# ```tsx
# import {
#   Dropdown,
#   DropdownContent,
#   DropdownItem,
#   DropdownItemIcon,
#   DropdownTrigger,
# } from "@govtechmy/myds-react/dropdown";
# export default function component() {
# 	return (<Dropdown>
# 		    <DropdownTrigger asChild>
# 		        <Button variant="primary-fill">With Disabled Item </Button>
# 		    </DropdownTrigger>
# 		    <DropdownContent>
# 		        <DropdownItem disabled>
# 		            <DropdownItemIcon>
# 		                <LogoutIcon />
# 		            </DropdownItemIcon>
# 		            <span className="text-inherit">Logout</span>
# 		        </DropdownItem>
# 		    </DropdownContent>
# 		</Dropdown>
# 	);
# }
# ```
#
# ```tsx
# import {
#   Dropdown,
#   DropdownContent,
#   DropdownItem,
#   DropdownItemIcon,
#   DropdownTrigger,
# } from "@govtechmy/myds-react/dropdown";
# export default function component() {
# 	return (// Start
# 		<Dropdown>
# 		    <DropdownTrigger asChild>
# 		        <Button variant="primary-fill">Align: Start </Button>
# 		    </DropdownTrigger>
# 		    <DropdownContent align="start">
# 		        <DropdownItem>Option 1</DropdownItem>
# 		        <DropdownItem>Option 2</DropdownItem>
# 		        <DropdownItem>Option 3</DropdownItem>
# 		    </DropdownContent>
# 		</Dropdown>
#
# 		// Center
#
# 		<Dropdown>
# 		  <DropdownTrigger asChild>
# 		    <Button variant="primary-fill">Align: Center </Button>
# 		  </DropdownTrigger>
# 		  <DropdownContent align="center">
# 		    <DropdownItem>Option 1</DropdownItem>
# 		    <DropdownItem>Option 2</DropdownItem>
# 		    <DropdownItem>Option 3</DropdownItem>
# 		  </DropdownContent>
# 		</Dropdown>
#
# 		// End
#
# 		<Dropdown>
# 		  <DropdownTrigger asChild>
# 		    <Button variant="primary-fill">Align: End </Button>
# 		  </DropdownTrigger>
# 		  <DropdownContent align="end">
# 		    <DropdownItem>Option 1</DropdownItem>
# 		    <DropdownItem>Option 2</DropdownItem>
# 		    <DropdownItem>Option 3</DropdownItem>
# 		  </DropdownContent>
# 		</Dropdown>
# 	);
# }
# ```
#
# ```tsx
# import {
#   Dropdown,
#   DropdownContent,
#   DropdownItem,
#   DropdownItemIcon,
#   DropdownTrigger,
# } from "@govtechmy/myds-react/dropdown";
# export default function component() {
# 	return (// Bottom
# 		 <Dropdown>
# 		    <DropdownTrigger asChild>
# 		        <Button variant="primary-fill">Side: Bottom </Button>
# 		    </DropdownTrigger>
# 		    <DropdownContent side="bottom">
# 		        <DropdownItem>Option 1</DropdownItem>
# 		        <DropdownItem>Option 2</DropdownItem>
# 		        <DropdownItem>Option 3</DropdownItem>
# 		    </DropdownContent>
# 		</Dropdown>
#
# 		// Top
#
# 		<Dropdown>
# 		  <DropdownTrigger asChild>
# 		    <Button variant="primary-fill">Side: Top </Button>
# 		  </DropdownTrigger>
# 		  <DropdownContent side="top">
# 		    <DropdownItem>Option 1</DropdownItem>
# 		    <DropdownItem>Option 2</DropdownItem>
# 		    <DropdownItem>Option 3</DropdownItem>
# 		  </DropdownContent>
# 		</Dropdown>
#
# 		// Left
#
# 		<Dropdown>
# 		  <DropdownTrigger asChild>
# 		    <Button variant="primary-fill">Side: Left </Button>
# 		  </DropdownTrigger>
# 		  <DropdownContent side="left">
# 		    <DropdownItem>Option 1</DropdownItem>
# 		    <DropdownItem>Option 2</DropdownItem>
# 		    <DropdownItem>Option 3</DropdownItem>
# 		  </DropdownContent>
# 		</Dropdown>
#
# 		// Right
#
# 		<Dropdown>
# 		  <DropdownTrigger asChild>
# 		    <Button variant="primary-fill">Side: Right </Button>
# 		  </DropdownTrigger>
# 		  <DropdownContent side="right">
# 		    <DropdownItem>Option 1</DropdownItem>
# 		    <DropdownItem>Option 2</DropdownItem>
# 		    <DropdownItem>Option 3</DropdownItem>
# 		  </DropdownContent>
# 		</Dropdown>
# 	);
# }
# ```
#
# ## API reference for `Dropdown` :
#
# ### Dropdown
#
# |              | description                                  | type                    | default   | typeDescription   |
# |--------------|----------------------------------------------|-------------------------|-----------|-------------------|
# | open         | State of the dropdown (controlled)           | boolean                 | false     | -                 |
# | defaultOpen  | Initial state of the dropdown (uncontrolled) | boolean                 | false     | -                 |
# | onOpenChange | Change event listener (controlled)           | (open: boolean) => void | -         | -                 |
#
# ### DropdownTrigger
#
# |         | description                              | type    | default   | typeDescription   |
# |---------|------------------------------------------|---------|-----------|-------------------|
# | asChild | Flag to inherit child component directly | boolean | false     | -                 |
#
# ### DropdownContent
#
# |       | description                                  | type   | default   | typeDescription             |
# |-------|----------------------------------------------|--------|-----------|-----------------------------|
# | align | Alignment of the dropdown wrt to the trigger | enum   | end       | start | end | center        |
# | side  | Position of the dropdown wrt to the trigger  | enum   | bottom    | top | bottom | left | right |
#
# ### DropdownItem
#
# |          | description                                   | type                   | default   | typeDescription   |
# |----------|-----------------------------------------------|------------------------|-----------|-------------------|
# | disabled | Whether the dropdown item is disabled         | boolean                | false     | -                 |
# | variant  | Variant of the dropdown item                  | default | danger       | default   | -                 |
# | onSelect | Event listener when dropdown item is selected | (event: Event) => void | -         | -                 |
#
# # Suggested library component (9/11) : Toggle
# - The Toggle component is a versatile switch that allows users to toggle between two states.
# ## Toggle can be imported into the new component like this:
# ```tsx
# import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
# ```
#
# ---
#
# ## examples of how `Toggle` can be used inside the new component:
# ```tsx
# export default () => (
#   <Toggle>
#     <ToggleThumb />
#   </Toggle>
# );
# ```
#
#
# ## full code examples of React components that use `Toggle` :
# ```tsx
# import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
# export default function component() {
# 	return (import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
#
# 		<Toggle size="small">
# 		  <ToggleThumb />
# 		</Toggle>
#
# 		<Toggle size="medium">
# 		  <ToggleThumb />
# 		</Toggle>
#
# 		<Toggle size="large">
# 		  <ToggleThumb />
# 		</Toggle>
# 	);
# }
# ```
#
# ```tsx
# import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
# export default function component() {
# 	return (import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
#
# 		<Toggle disabled = {true}>
# 		    <ToggleThumb />
# 		</Toggle>
#
# 		<Toggle disabled = {true} defaultChecked = {true}>
# 		    <ToggleThumb />
# 		</Toggle>
# 	);
# }
# ```
#
# ```tsx
# import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
# export default function component() {
# 	return (import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
#
# 		const ControlledToggle = () => {
# 		const [isChecked, setIsChecked] = React.useState(false);
# 		return (
#
# 		<div className="flex flex-col items-center justify-center">
# 		  <p>Current state: {isChecked ? "On" : "Off"}</p>
# 		  <Toggle checked={isChecked} onCheckedChange={setIsChecked}>
# 		    <ToggleThumb />
# 		  </Toggle>
# 		</div>
# 		); };
# 	);
# }
# ```
#
# ```tsx
# import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
# export default function component() {
# 	return (import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
#
# 		<p className="">This toggle manages its own state internally.</p>
# 		<Toggle defaultChecked={false}>
# 		  <ToggleThumb />
# 		</Toggle>
# 	);
# }
# ```
#
# ## API reference for `Toggle` :
#
# ### Toggle
#
# |          | description                              | type    | default   | typeDescription        |
# |----------|------------------------------------------|---------|-----------|------------------------|
# | size     | Sizes of the toggle                      | enum    | medium    | small | medium | large |
# | disabled | Indicates whether the toggle is disabled | boolean | false     | true | false           |
#
# # Suggested library component (10/11) : Checkbox
# - Allows users to make a binary choice, such as selecting or not selecting an option. It is commonly used in forms, settings, and filters to capture user input and preferences.
# ## Checkbox can be imported into the new component like this:
# ```tsx
# import { Checkbox } from "@govtechmy/myds-react/checkbox";
# ```
#
# ---
#
# ## examples of how `Checkbox` can be used inside the new component:
# ```tsx
# export default () => <Checkbox />;
# ```
#
#
# ## full code examples of React components that use `Checkbox` :
# ```tsx
# import { Checkbox } from "@govtechmy/myds-react/checkbox";
# export default function component() {
# 	return (<Checkbox defaultChecked size="small" />
# 		<Checkbox defaultChecked size="medium" />
# 		<Checkbox defaultChecked size="large" />
# 	);
# }
# ```
#
# ```tsx
# import { Checkbox } from "@govtechmy/myds-react/checkbox";
# export default function component() {
# 	return (// Uncontrolled state
# 		<Label>
# 		  <Checkbox defaultChecked />
# 		  <span>Uncontrolled state</span>
# 		</Label>
#
# 		// Controlled state
# 		<Label>
# 		  <Checkbox checked={true} />
# 		  <span>Controlled state</span>
# 		</Label>
# 	);
# }
# ```
#
# ```tsx
# import { Checkbox } from "@govtechmy/myds-react/checkbox";
# export default function component() {
# 	return (<Label>
# 		  <Checkbox defaultChecked disabled />
# 		  <span>Disabled state</span>
# 		</Label>
# 	);
# }
# ```
#
# ```tsx
# import { Checkbox } from "@govtechmy/myds-react/checkbox";
# export default function component() {
# 	return (<Label>
# 		  <Checkbox defaultChecked="indeterminate" />
# 		  <span>Indeterminate state</span>
# 		</Label>
# 	);
# }
# ```
#
# ## API reference for `Checkbox` :
#
# ### Checkbox
#
# |                 | description                                          | type                                       | default   | typeDescription        |
# |-----------------|------------------------------------------------------|--------------------------------------------|-----------|------------------------|
# | size            | Size of the checkbox                                 | enum                                       | small     | small | medium | large |
# | defaultChecked  | Initial checked state of the checkbox (uncontrolled) | boolean | indeterminate                    | false     | -                      |
# | checked         | State of the checkbox (controlled)                   | boolean | indeterminate                    | false     | -                      |
# | onCheckedChange | Checked event listener (controlled)                  | (checked: boolean | indeterminate) => void | false     | -                      |
#
# Icon elements can optionally be used when making the React component.
#
# ---
#
# # example: importing icons in the component (only import the ones you need) :
#
# ```tsx
# import { CheckIcon , CheckCircleIcon , CheckCircleFillIcon , CheckmarkShieldIcon , Checkmark14PointStarIcon , BellIcon , CrossIcon , LockIcon , PinIcon , ChevronLeftFillIcon } from @govtechmy/myds-react/icon
# ```
#
# # example: using an icon inside the component :
#
# ```tsx
# <CheckIcon className="h-4 w-4" />
# ```
#
# ---
#
#
# Here are some available icons that might be relevant to the component you are making. You can choose from them if relevant :
#
# ```
# - CheckIcon
# - CheckCircleIcon
# - CheckCircleFillIcon
# - CheckmarkShieldIcon
# - Checkmark14PointStarIcon
# - BellIcon
# - CrossIcon
# - LockIcon
# - PinIcon
# - ChevronLeftFillIcon
# ```
#
# **When creating components you are to adhere to the Malaysian Design System**
# Keeep in mind components created should have neat and organized layout !
#
# # Malaysian Design System Guidelines
#
# This document summarizes the Malaysian Design System (MYDS) guidelines for use by frontend web developers.
#
# ## Grid System (12-8-4)
#
# MYDS uses a responsive 12-8-4 grid system to ensure layouts adapt well to different screen sizes.
#
# **Breakpoints:**
#
# - **Desktop:**  Screens ≥ 1024px width
# - **Tablet:** Screens 768px - 1023px width
# - **Mobile:** Screens ≤ 767px width
#
# **Grid Specifications:**
#
# | Screen Size | Grid Columns | Column Gap | Edge Padding | Max Content Width |
# |---|---|---|---|---|
# | **Desktop (≥1024px)** | 12 Columns | 24px | Yes | 1280px |
# | **Tablet (768px - 1023px)** | 8 Columns | 24px | Yes | N/A (Adapts to screen) |
# | **Mobile (≤767px)** | 4 Columns | 18px | Yes | N/A (Adapts to screen) |
#
# **Container Types and Width Behavior:**
#
# - **Content:** Flexible container for general content layouts, adapts to the grid system.
# - **Article:** Container for long-form text, maximum width of 640px for comfortable reading.
# - **Images & Interactive Charts:** Can span article width (640px) or extend up to 740px for more visual impact.
#
# ## Radius
#
# MYDS uses consistent corner radii to create a modern and unified look.
#
# **Radius Specifications:**
#
# | Name          | Size  | Usage Examples              |
# |---------------|-------|------------------------------|
# | **Extra Small** | `4px` | Context Menu Item            |
# | **Small**       | `6px` | Small Button                 |
# | **Medium**      | `8px` | Button, CTA, Context Menu     |
# | **Large**       | `12px`| Content Card                 |
# | **Extra Large** | `14px`| Context Menu with Search field |
#
# ## Shadow
#
# Shadows are used to add depth and visual hierarchy to UI elements.
#
# **Shadow Specifications:**
#
# | Name           | CSS `box-shadow` Value                                    |
# |----------------|------------------------------------------------------------|
# | **Button**       | `0px 1px 3px 0px rgba(0, 0, 0, 0.07)`                    |
# | **Card**         | `0px 2px 6px 0px rgba(0, 0, 0, 0.05),`<br>`0px 6px 24px 0px rgba(0, 0, 0, 0.05)` |
# | **Context Menu** | `0px 2px 6px 0px rgba(0, 0, 0, 0.05),`<br>`0px 12px 50px 0px rgba(0, 0, 0, 0.10)` |
#
# ## Spacing
#
# Consistent spacing is crucial for creating visually balanced and harmonious layouts. MYDS defines specific spacing values to be used across components.
#
# **Spacing Sizes and Usage Examples:**
#
# | Size  | Usage Examples                                |
# |-------|------------------------------------------------|
# | **4px**   |                                                |
# | **8px**   | Gap in button groups, fields and labels        |
# | **12px**  |                                                |
# | **16px**  |                                                |
# | **20px**  |                                                |
# | **24px**  | Gap between subsections, cards              |
# | **32px**  | Gap between main sections                     |
# | **40px**  |                                                |
# | **48px**  |                                                |
# | **64px**  |                                                |
#
# ## Colour
#
# **Corresponding colours of primitive tokens**:
# - primary: blue
# - danger: red
# - success: green
# - warning: yellow
#
# ### Primitive Colours
#
# - `white`
# - `black`
# - `gray-50`
# - `gray-100`
# - `gray-200`
# - `gray-300`
# - `gray-400`
# - `gray-500`
# - `gray-600`
# - `gray-700`
# - `gray-800`
# - `gray-850`
# - `gray-900`
# - `gray-930`
# - `gray-950`
# - `primary-50`
# - `primary-100`
# - `primary-200`
# - `primary-300`
# - `primary-400`
# - `primary-500`
# - `primary-600`
# - `primary-700`
# - `primary-800`
# - `primary-900`
# - `primary-950`
# - `danger-50`
# - `danger-100`
# - `danger-200`
# - `danger-300`
# - `danger-400`
# - `danger-500`
# - `danger-600`
# - `danger-700`
# - `danger-800`
# - `danger-900`
# - `danger-950`
# - `success-50`
# - `success-100`
# - `success-200`
# - `success-300`
# - `success-400`
# - `success-500`
# - `success-600`
# - `success-700`
# - `success-800`
# - `success-900`
# - `success-950`
# - `warning-50`
# - `warning-100`
# - `warning-200`
# - `warning-300`
# - `warning-400`
# - `warning-500`
# - `warning-600`
# - `warning-700`
# - `warning-800`
# - `warning-900`
# - `warning-950`

# %%
taskObjectWithContext = {"task":taskObject, "context":generationContext}
generation_response = re.post(F"{API_ENDPOINT}/api/py/generate_component", json=taskObjectWithContext)
generatedCode = generation_response.json()
print(generatedCode)
# Out:
# ```tsx
# import React from 'react';
# import {
#   Tabs,
#   TabsList,
#   TabsTrigger,
#   TabsContent,
# } from "@govtechmy/myds-react/tabs";
# import { Tag } from "@govtechmy/myds-react/tag";
# import { Button } from "@govtechmy/myds-react/button";
# import { CheckIcon } from "@govtechmy/myds-react/icon";
#
# const PricingComponent_7d278b55_ab8b_4d69_9de4_ab792abecc5d = () => {
#   return (
#     <div className="container mx-auto px-4 py-8">
#       <div className="text-center mb-8">
#         <h2 className="text-2xl font-bold text-gray-900 dark:text-white">Pricing Component</h2>
#       </div>
#       <Tabs defaultValue="yearly" variant="enclosed">
#         <TabsList className="w-full justify-center">
#           <TabsTrigger value="monthly">Monthly</TabsTrigger>
#           <TabsTrigger value="yearly">Yearly</TabsTrigger>
#         </TabsList>
#         <TabsContent value="monthly" className="mt-8">
#           <div className="grid grid-cols-1 md:grid-cols-3 gap-6">
#             {/* Basic Plan */}
#             <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#               <div>
#                 <h3 className="text-xl font-semibold text-gray-900 mb-4 dark:text-white">Basic Plan</h3>
#                 <Tag variant="primary" mode="pill" size="small" className="mb-4">Most Popular</Tag>
#                 <div className="text-gray-700 dark:text-gray-300">
#                   <p className="text-2xl font-bold text-primary-500 mb-4">$9/month</p>
#                   <ul className="space-y-2">
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 1
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 2
#                     </li>
#                   </ul>
#                 </div>
#               </div>
#               <div className="mt-6">
#                 <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                   Choose Plan
#                 </Button>
#               </div>
#             </div>
#
#             {/* Standard Plan */}
#             <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#               <div>
#                 <h3 className="text-xl font-semibold text-gray-900 mb-8 dark:text-white">Standard Plan</h3>
#                 <div className="text-gray-700 dark:text-gray-300">
#                   <p className="text-2xl font-bold text-primary-500 mb-4">$19/month</p>
#                   <ul className="space-y-2">
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 1
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 2
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 3
#                     </li>
#                   </ul>
#                 </div>
#               </div>
#               <div className="mt-6">
#                 <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                   Choose Plan
#                 </Button>
#               </div>
#             </div>
#
#             {/* Premium Plan */}
#             <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#               <div>
#                 <h3 className="text-xl font-semibold text-gray-900 mb-8 dark:text-white">Premium Plan</h3>
#                 <div className="text-gray-700 dark:text-gray-300">
#                   <p className="text-2xl font-bold text-primary-500 mb-4">$29/month</p>
#                   <ul className="space-y-2">
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 1
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 2
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 3
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 4
#                     </li>
#                   </ul>
#                 </div>
#               </div>
#               <div className="mt-6">
#                 <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                   Choose Plan
#                 </Button>
#               </div>
#             </div>
#           </div>
#         </TabsContent>
#         <TabsContent value="yearly" className="mt-8">
#           <div className="grid grid-cols-1 md:grid-cols-3 gap-6">
#             {/* Basic Plan */}
#             <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#               <div>
#                 <h3 className="text-xl font-semibold text-gray-900 mb-4 dark:text-white">Basic Plan</h3>
#                 <Tag variant="primary" mode="pill" size="small" className="mb-4">Most Popular</Tag>
#                 <div className="text-gray-700 dark:text-gray-300">
#                   <p className="text-2xl font-bold text-primary-500 mb-4">$99/year</p>
#                   <ul className="space-y-2">
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 1
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 2
#                     </li>
#                   </ul>
#                 </div>
#               </div>
#               <div className="mt-6">
#                 <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                   Choose Plan
#                 </Button>
#               </div>
#             </div>
#
#             {/* Standard Plan */}
#             <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#               <div>
#                 <h3 className="text-xl font-semibold text-gray-900 mb-8 dark:text-white">Standard Plan</h3>
#                 <div className="text-gray-700 dark:text-gray-300">
#                   <p className="text-2xl font-bold text-primary-500 mb-4">$199/year</p>
#                   <ul className="space-y-2">
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 1
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 2
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 3
#                     </li>
#                   </ul>
#                 </div>
#               </div>
#               <div className="mt-6">
#                 <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                   Choose Plan
#                 </Button>
#               </div>
#             </div>
#
#             {/* Premium Plan */}
#             <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#               <div>
#                 <h3 className="text-xl font-semibold text-gray-900 mb-8 dark:text-white">Premium Plan</h3>
#                 <div className="text-gray-700 dark:text-gray-300">
#                   <p className="text-2xl font-bold text-primary-500 mb-4">$299/year</p>
#                   <ul className="space-y-2">
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 1
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 2
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 3
#                     </li>
#                     <li className="flex items-center gap-2">
#                       <CheckIcon className="h-4 w-4 text-success-500" />
#                       Feature 4
#                     </li>
#                   </ul>
#                 </div>
#               </div>
#               <div className="mt-6">
#                 <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                   Choose Plan
#                 </Button>
#               </div>
#             </div>
#           </div>
#         </TabsContent>
#       </Tabs>
#     </div>
#   );
# };
#
# export default PricingComponent_7d278b55_ab8b_4d69_9de4_ab792abecc5d;
# ```

# %%
#! Validation currently not working
# codeBody = {"tsx":generatedCode}
# validation_response = re.post(F"{API_ENDPOINT}/api/py/validate_code", json=codeBody)
# fixedCode = validation_response.json()
# print(fixedCode)

# %% [markdown]
# ## Updating an existing component

# %%
update_description = "add theme switcher"  # provide a description of desired update
updatedPrompt = {"task": taskObject,   "update_prompt": update_description, "wireframe": wireframe, "tsx": generatedCode} # use fixedCode when validation is available
update_task_response = re.post(F"{API_ENDPOINT}/api/py/task_planning_iter", json=updatedPrompt)
updatetaskObject = update_task_response.json()
print(json.dumps(updatetaskObject, indent=2))
# Out:
# {
#   "name": "PricingComponent_7d278b55-ab8b-4d69-9de4-ab792abecc5d",
#   "description": {
#     "user": "a pricing component for Saas",
#     "llm": "Displays different pricing plans for a SaaS product, highlighting features and benefits of each plan."
#   },
#   "icons": [
#     "checkicon"
#   ],
#   "components": [
#     {
#       "name": "Tabs",
#       "usage": "To organize different pricing plans into separate tabs for easy navigation."
#     },
#     {
#       "name": "Tag",
#       "usage": "To highlight the 'most popular' or 'recommended' plan."
#     },
#     {
#       "name": "Button",
#       "usage": "To provide a clear call-to-action for users to select a plan (e.g., 'Choose Plan', 'Get Started')."
#     },
#     {
#       "name": "Tooltip",
#       "usage": "To provide additional information or explanation about specific features in each plan."
#     },
#     {
#       "name": "Toggle",
#       "usage": "To allow users to switch between monthly and yearly billing cycles."
#     }
#   ],
#   "update": {
#     "update_prompt": "add theme switcher",
#     "update_description": "Added a Theme Switcher component to allow users to toggle between light and dark themes, enhancing user customization.",
#     "icons": [],
#     "components": [
#       {
#         "name": "Theme Switch",
#         "usage": "To allow users to switch between light and dark themes."
#       }
#     ],
#     "wireframe": true
#   }
# }

# %%
updatedWireframe = None
if updatetaskObject["update"]["wireframe"]:
    wireframe_update_body = {"task": updatetaskObject, "wireframe": wireframe}
    update_wireframe_response = re.post(F"{API_ENDPOINT}/api/py/wireframe_iter", json=wireframe_update_body)
    updatedWireframe = update_wireframe_response.json()
    print(updatedWireframe)
# Out:
# +---------------------------------------------------------------------------------------+
# |                                 Pricing Component                                     |
# |---------------------------------------------------------------------------------------|
# |  [Theme Switch]                                                                       |
# |  [Tabs: Monthly | Yearly (Selected)]                                                   |
# |---------------------------------------------------------------------------------------|
# |                                                                                       |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |  |    Basic Plan       |   |   Standard Plan     |   |    Premium Plan     |          |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |  |  [Tag: Most Popular] |   |                     |   |                     |          |
# |  |                     |   |                     |   |                     |          |
# |  |   Price: $X/month   |   |   Price: $Y/month   |   |   Price: $Z/month   |          |
# |  |                     |   |                     |   |                     |          |
# |  |   [checkicon] Feature 1|   |   [checkicon] Feature 1|   |   [checkicon] Feature 1|          |
# |  |   [checkicon] Feature 2|   |   [checkicon] Feature 2|   |   [checkicon] Feature 2|          |
# |  |                     |   |   [checkicon] Feature 3|   |   [checkicon] Feature 3|          |
# |  |                     |   |                     |   |   [checkicon] Feature 4|          |
# |  |                     |   |                     |   |                     |          |
# |  | [Button: Choose Plan]|   | [Button: Choose Plan]|   | [Button: Choose Plan]|          |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |                                                                                       |
# +---------------------------------------------------------------------------------------+

# %%
if updatedWireframe:
    context_update_body = {"task": updatetaskObject, "wireframe": updatedWireframe}
else:
    context_update_body = {"task": updatetaskObject, "wireframe": wireframe}
update_context_response = re.post(F"{API_ENDPOINT}/api/py/assemble_context_iter", json=context_update_body)
updatedContext = update_context_response.json()
print(updatedContext)
# Out:
# # Wireframe Design of the component
#
# **Adhere fully to the wireframe, crafted by an expert UIUX Designer when updating the component !**
#
# +---------------------------------------------------------------------------------------+
# |                                 Pricing Component                                     |
# |---------------------------------------------------------------------------------------|
# |  [Theme Switch]                                                                       |
# |  [Tabs: Monthly | Yearly (Selected)]                                                   |
# |---------------------------------------------------------------------------------------|
# |                                                                                       |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |  |    Basic Plan       |   |   Standard Plan     |   |    Premium Plan     |          |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |  |  [Tag: Most Popular] |   |                     |   |                     |          |
# |  |                     |   |                     |   |                     |          |
# |  |   Price: $X/month   |   |   Price: $Y/month   |   |   Price: $Z/month   |          |
# |  |                     |   |                     |   |                     |          |
# |  |   [checkicon] Feature 1|   |   [checkicon] Feature 1|   |   [checkicon] Feature 1|          |
# |  |   [checkicon] Feature 2|   |   [checkicon] Feature 2|   |   [checkicon] Feature 2|          |
# |  |                     |   |   [checkicon] Feature 3|   |   [checkicon] Feature 3|          |
# |  |                     |   |                     |   |   [checkicon] Feature 4|          |
# |  |                     |   |                     |   |                     |          |
# |  | [Button: Choose Plan]|   | [Button: Choose Plan]|   | [Button: Choose Plan]|          |
# |  +---------------------+   +---------------------+   +---------------------+          |
# |                                                                                       |
# +---------------------------------------------------------------------------------------+
#
# ---
# **Library components to be used while making the new React component.**
#
# # Suggested library component usages:
# - Theme Switch - To allow users to switch between light and dark themes.
#
# # Suggested library component (0/2) : Theme Switch
# - A component that allows users to switching themes of the application dynamically.
# ## Theme Switch can be imported into the new component like this:
# ```tsx
# import { ThemeProvider } from "@govtechmy/myds-react/hooks";
# import { ThemeSwitch } from "@govtechmy/myds-react/theme-switch";
# ```
#
# ---
#
# ## examples of how `Theme Switch` can be used inside the new component:
# ```tsx
# export default () => (
#   <ThemeProvider>
#     <ThemeSwitch />
#   </ThemeProvider>
# );
# ```
#
#
# ## full code examples of React components that use `Theme Switch` :
# ```tsx
# import { ThemeProvider } from "@govtechmy/myds-react/hooks";
# import { ThemeSwitch } from "@govtechmy/myds-react/theme-switch";
# export default function component() {
# 	return (import { ThemeProvider } from "@govtechmy/myds-react/hooks";
# 		import { ThemeSwitch } from "@govtechmy/myds-react/theme-switch";
#
# 		<ThemeProvider>
# 		  <ThemeSwitch as="toggle" />
# 		</ThemeProvider>
# 	);
# }
# ```
#
# ```tsx
# import { ThemeProvider } from "@govtechmy/myds-react/hooks";
# import { ThemeSwitch } from "@govtechmy/myds-react/theme-switch";
# export default function component() {
# 	return (import { ThemeProvider } from "@govtechmy/myds-react/hooks";
# 		import { ThemeSwitch } from "@govtechmy/myds-react/theme-switch";
#
# 		<ThemeProvider>
# 		  <ThemeSwitch as="select" />
# 		</ThemeProvider>
# 	);
# }
# ```
#
# ```tsx
# import { ThemeProvider } from "@govtechmy/myds-react/hooks";
# import { ThemeSwitch } from "@govtechmy/myds-react/theme-switch";
# export default function component() {
# 	return (import { ThemeProvider } from "@govtechmy/myds-react/hooks";
# 		import { ThemeSwitch } from "@govtechmy/myds-react/theme-switch";
#
# 		<ThemeProvider>
# 		  <ThemeSwitch
# 		    as="toggle"
# 		    themes={[
# 		      {
# 		        icon: "🌞",
# 		        label: "Light",
# 		        value: "light",
# 		      },
# 		      {
# 		        icon: "🌚",
# 		        label: "Dark",
# 		        value: "dark",
# 		      },
# 		      {
# 		        icon: "🌐",
# 		        label: "System",
# 		        value: "system",
# 		      },
# 		    ]}
# 		  />
# 		  <ThemeSwitch
# 		    as="select"
# 		    themes={[
# 		      {
# 		        icon: "🌞",
# 		        label: "Light",
# 		        value: "light",
# 		      },
# 		      {
# 		        icon: "🌚",
# 		        label: "Dark",
# 		        value: "dark",
# 		      },
# 		      {
# 		        icon: "🌐",
# 		        label: "System",
# 		        value: "system",
# 		      },
# 		    ]}
# 		  />
# 		</ThemeProvider>
# 	);
# }
# ```
#
# ## API reference for `Theme Switch` :
#
# ### ThemeSwitch
#
# |        | description                                                                     | type    | default                                                                                                                                                                                 | typeDescription                                                                | as                     |
# |--------|---------------------------------------------------------------------------------|---------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------|------------------------|
# | as     | -                                                                               | enum    | toggle                                                                                                                                                                                  | toggle | select                                                                | Component to appear as |
# | themes | An array of theme objects, each containing a theme name and an associated icon. | Theme[] | [
#     {
#       "label": "Light",
#       "value": "light",
#       "icon": <SunIcon />;
#     },
#     {
#       "label": "Dark",
#       "value": "dark",
#       "icon": <MoonIcon />;
#     }
# ] | type Theme = {
#   "label": string,
#   "value": string,
#   "icon": ReactNode;
# } | -                      |
#
# ### ThemeProvider
#
# |              | description                                      | type      | default   | typeDescription   |
# |--------------|--------------------------------------------------|-----------|-----------|-------------------|
# | defaultTheme | The default theme to be applied.                 | string    | light     | Theme name        |
# | children     | The children components wrapped by the provider. | ReactNode | -         | -                 |
#
# # Suggested library component (1/2) : Toggle
# - The Toggle component is a versatile switch that allows users to toggle between two states.
# ## Toggle can be imported into the new component like this:
# ```tsx
# import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
# ```
#
# ---
#
# ## examples of how `Toggle` can be used inside the new component:
# ```tsx
# export default () => (
#   <Toggle>
#     <ToggleThumb />
#   </Toggle>
# );
# ```
#
#
# ## full code examples of React components that use `Toggle` :
# ```tsx
# import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
# export default function component() {
# 	return (import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
#
# 		<Toggle size="small">
# 		  <ToggleThumb />
# 		</Toggle>
#
# 		<Toggle size="medium">
# 		  <ToggleThumb />
# 		</Toggle>
#
# 		<Toggle size="large">
# 		  <ToggleThumb />
# 		</Toggle>
# 	);
# }
# ```
#
# ```tsx
# import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
# export default function component() {
# 	return (import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
#
# 		<Toggle disabled = {true}>
# 		    <ToggleThumb />
# 		</Toggle>
#
# 		<Toggle disabled = {true} defaultChecked = {true}>
# 		    <ToggleThumb />
# 		</Toggle>
# 	);
# }
# ```
#
# ```tsx
# import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
# export default function component() {
# 	return (import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
#
# 		const ControlledToggle = () => {
# 		const [isChecked, setIsChecked] = React.useState(false);
# 		return (
#
# 		<div className="flex flex-col items-center justify-center">
# 		  <p>Current state: {isChecked ? "On" : "Off"}</p>
# 		  <Toggle checked={isChecked} onCheckedChange={setIsChecked}>
# 		    <ToggleThumb />
# 		  </Toggle>
# 		</div>
# 		); };
# 	);
# }
# ```
#
# ```tsx
# import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
# export default function component() {
# 	return (import { Toggle, ToggleThumb } from "@govtechmy/myds-react/toggle";
#
# 		<p className="">This toggle manages its own state internally.</p>
# 		<Toggle defaultChecked={false}>
# 		  <ToggleThumb />
# 		</Toggle>
# 	);
# }
# ```
#
# ## API reference for `Toggle` :
#
# ### Toggle
#
# |          | description                              | type    | default   | typeDescription        |
# |----------|------------------------------------------|---------|-----------|------------------------|
# | size     | Sizes of the toggle                      | enum    | medium    | small | medium | large |
# | disabled | Indicates whether the toggle is disabled | boolean | false     | true | false           |
#
#
# **When creating components you are to adhere to the Malaysian Design System**
# Keeep in mind components created should have neat and organized layout !
#
# # Malaysian Design System Guidelines
#
# This document summarizes the Malaysian Design System (MYDS) guidelines for use by frontend web developers.
#
# ## Grid System (12-8-4)
#
# MYDS uses a responsive 12-8-4 grid system to ensure layouts adapt well to different screen sizes.
#
# **Breakpoints:**
#
# - **Desktop:**  Screens ≥ 1024px width
# - **Tablet:** Screens 768px - 1023px width
# - **Mobile:** Screens ≤ 767px width
#
# **Grid Specifications:**
#
# | Screen Size | Grid Columns | Column Gap | Edge Padding | Max Content Width |
# |---|---|---|---|---|
# | **Desktop (≥1024px)** | 12 Columns | 24px | Yes | 1280px |
# | **Tablet (768px - 1023px)** | 8 Columns | 24px | Yes | N/A (Adapts to screen) |
# | **Mobile (≤767px)** | 4 Columns | 18px | Yes | N/A (Adapts to screen) |
#
# **Container Types and Width Behavior:**
#
# - **Content:** Flexible container for general content layouts, adapts to the grid system.
# - **Article:** Container for long-form text, maximum width of 640px for comfortable reading.
# - **Images & Interactive Charts:** Can span article width (640px) or extend up to 740px for more visual impact.
#
# ## Radius
#
# MYDS uses consistent corner radii to create a modern and unified look.
#
# **Radius Specifications:**
#
# | Name          | Size  | Usage Examples              |
# |---------------|-------|------------------------------|
# | **Extra Small** | `4px` | Context Menu Item            |
# | **Small**       | `6px` | Small Button                 |
# | **Medium**      | `8px` | Button, CTA, Context Menu     |
# | **Large**       | `12px`| Content Card                 |
# | **Extra Large** | `14px`| Context Menu with Search field |
#
# ## Shadow
#
# Shadows are used to add depth and visual hierarchy to UI elements.
#
# **Shadow Specifications:**
#
# | Name           | CSS `box-shadow` Value                                    |
# |----------------|------------------------------------------------------------|
# | **Button**       | `0px 1px 3px 0px rgba(0, 0, 0, 0.07)`                    |
# | **Card**         | `0px 2px 6px 0px rgba(0, 0, 0, 0.05),`<br>`0px 6px 24px 0px rgba(0, 0, 0, 0.05)` |
# | **Context Menu** | `0px 2px 6px 0px rgba(0, 0, 0, 0.05),`<br>`0px 12px 50px 0px rgba(0, 0, 0, 0.10)` |
#
# ## Spacing
#
# Consistent spacing is crucial for creating visually balanced and harmonious layouts. MYDS defines specific spacing values to be used across components.
#
# **Spacing Sizes and Usage Examples:**
#
# | Size  | Usage Examples                                |
# |-------|------------------------------------------------|
# | **4px**   |                                                |
# | **8px**   | Gap in button groups, fields and labels        |
# | **12px**  |                                                |
# | **16px**  |                                                |
# | **20px**  |                                                |
# | **24px**  | Gap between subsections, cards              |
# | **32px**  | Gap between main sections                     |
# | **40px**  |                                                |
# | **48px**  |                                                |
# | **64px**  |                                                |
#
# ## Colour
#
# **Corresponding colours of primitive tokens**:
# - primary: blue
# - danger: red
# - success: green
# - warning: yellow
#
# ### Primitive Colours
#
# - `white`
# - `black`
# - `gray-50`
# - `gray-100`
# - `gray-200`
# - `gray-300`
# - `gray-400`
# - `gray-500`
# - `gray-600`
# - `gray-700`
# - `gray-800`
# - `gray-850`
# - `gray-900`
# - `gray-930`
# - `gray-950`
# - `primary-50`
# - `primary-100`
# - `primary-200`
# - `primary-300`
# - `primary-400`
# - `primary-500`
# - `primary-600`
# - `primary-700`
# - `primary-800`
# - `primary-900`
# - `primary-950`
# - `danger-50`
# - `danger-100`
# - `danger-200`
# - `danger-300`
# - `danger-400`
# - `danger-500`
# - `danger-600`
# - `danger-700`
# - `danger-800`
# - `danger-900`
# - `danger-950`
# - `success-50`
# - `success-100`
# - `success-200`
# - `success-300`
# - `success-400`
# - `success-500`
# - `success-600`
# - `success-700`
# - `success-800`
# - `success-900`
# - `success-950`
# - `warning-50`
# - `warning-100`
# - `warning-200`
# - `warning-300`
# - `warning-400`
# - `warning-500`
# - `warning-600`
# - `warning-700`
# - `warning-800`
# - `warning-900`
# - `warning-950`

# %%
component_update_body = {"task": updatetaskObject, "context": updatedContext, "tsx": generatedCode}
update_component_response = re.post(F"{API_ENDPOINT}/api/py/generate_component_iterate", json=component_update_body)
updatedComponentCode = update_component_response.json()
print(updatedComponentCode)
# Out:
# import React from 'react';
# import {
#   Tabs,
#   TabsList,
#   TabsTrigger,
#   TabsContent,
# } from "@govtechmy/myds-react/tabs";
# import { Tag } from "@govtechmy/myds-react/tag";
# import { Button } from "@govtechmy/myds-react/button";
# import { CheckIcon } from "@govtechmy/myds-react/icon";
# import { ThemeProvider } from "@govtechmy/myds-react/hooks";
# import { ThemeSwitch } from "@govtechmy/myds-react/theme-switch";
#
# const PricingComponent_7d278b55_ab8b_4d69_9de4_ab792abecc5d = () => {
#   return (
#     <ThemeProvider>
#       <div className="container mx-auto px-4 py-8">
#         <div className="flex justify-between items-center mb-8">
#           <h2 className="text-2xl font-bold text-gray-900 dark:text-white">
#             Pricing Component
#           </h2>
#           <ThemeSwitch />
#         </div>
#         <Tabs defaultValue="yearly" variant="enclosed">
#           <TabsList className="w-full justify-center">
#             <TabsTrigger value="monthly">Monthly</TabsTrigger>
#             <TabsTrigger value="yearly">Yearly</TabsTrigger>
#           </TabsList>
#           <TabsContent value="monthly" className="mt-8">
#             <div className="grid grid-cols-1 md:grid-cols-3 gap-6">
#               {/* Basic Plan */}
#               <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#                 <div>
#                   <h3 className="text-xl font-semibold text-gray-900 mb-4 dark:text-white">
#                     Basic Plan
#                   </h3>
#                   <Tag variant="primary" mode="pill" size="small" className="mb-4">
#                     Most Popular
#                   </Tag>
#                   <div className="text-gray-700 dark:text-gray-300">
#                     <p className="text-2xl font-bold text-primary-500 mb-4">
#                       $9/month
#                     </p>
#                     <ul className="space-y-2">
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 1
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 2
#                       </li>
#                     </ul>
#                   </div>
#                 </div>
#                 <div className="mt-6">
#                   <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                     Choose Plan
#                   </Button>
#                 </div>
#               </div>
#
#               {/* Standard Plan */}
#               <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#                 <div>
#                   <h3 className="text-xl font-semibold text-gray-900 mb-8 dark:text-white">
#                     Standard Plan
#                   </h3>
#                   <div className="text-gray-700 dark:text-gray-300">
#                     <p className="text-2xl font-bold text-primary-500 mb-4">
#                       $19/month
#                     </p>
#                     <ul className="space-y-2">
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 1
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 2
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 3
#                       </li>
#                     </ul>
#                   </div>
#                 </div>
#                 <div className="mt-6">
#                   <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                     Choose Plan
#                   </Button>
#                 </div>
#               </div>
#
#               {/* Premium Plan */}
#               <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#                 <div>
#                   <h3 className="text-xl font-semibold text-gray-900 mb-8 dark:text-white">
#                     Premium Plan
#                   </h3>
#                   <div className="text-gray-700 dark:text-gray-300">
#                     <p className="text-2xl font-bold text-primary-500 mb-4">
#                       $29/month
#                     </p>
#                     <ul className="space-y-2">
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 1
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 2
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 3
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 4
#                       </li>
#                     </ul>
#                   </div>
#                 </div>
#                 <div className="mt-6">
#                   <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                     Choose Plan
#                   </Button>
#                 </div>
#               </div>
#             </div>
#           </TabsContent>
#           <TabsContent value="yearly" className="mt-8">
#             <div className="grid grid-cols-1 md:grid-cols-3 gap-6">
#               {/* Basic Plan */}
#               <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#                 <div>
#                   <h3 className="text-xl font-semibold text-gray-900 mb-4 dark:text-white">
#                     Basic Plan
#                   </h3>
#                   <Tag variant="primary" mode="pill" size="small" className="mb-4">
#                     Most Popular
#                   </Tag>
#                   <div className="text-gray-700 dark:text-gray-300">
#                     <p className="text-2xl font-bold text-primary-500 mb-4">
#                       $99/year
#                     </p>
#                     <ul className="space-y-2">
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 1
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 2
#                       </li>
#                     </ul>
#                   </div>
#                 </div>
#                 <div className="mt-6">
#                   <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                     Choose Plan
#                   </Button>
#                 </div>
#               </div>
#
#               {/* Standard Plan */}
#               <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#                 <div>
#                   <h3 className="text-xl font-semibold text-gray-900 mb-8 dark:text-white">
#                     Standard Plan
#                   </h3>
#                   <div className="text-gray-700 dark:text-gray-300">
#                     <p className="text-2xl font-bold text-primary-500 mb-4">
#                       $199/year
#                     </p>
#                     <ul className="space-y-2">
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 1
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 2
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 3
#                       </li>
#                     </ul>
#                   </div>
#                 </div>
#                 <div className="mt-6">
#                   <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                     Choose Plan
#                   </Button>
#                 </div>
#               </div>
#
#               {/* Premium Plan */}
#               <div className="bg-white rounded-lg shadow-md p-6 flex flex-col justify-between dark:bg-gray-800 dark:shadow-none border dark:border-gray-700">
#                 <div>
#                   <h3 className="text-xl font-semibold text-gray-900 mb-8 dark:text-white">
#                     Premium Plan
#                   </h3>
#                   <div className="text-gray-700 dark:text-gray-300">
#                     <p className="text-2xl font-bold text-primary-500 mb-4">
#                       $299/year
#                     </p>
#                     <ul className="space-y-2">
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 1
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 2
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 3
#                       </li>
#                       <li className="flex items-center gap-2">
#                         <CheckIcon className="h-4 w-4 text-success-500" />
#                         Feature 4
#                       </li>
#                     </ul>
#                   </div>
#                 </div>
#                 <div className="mt-6">
#                   <Button variant="primary-fill" size="medium" className="w-full justify-center">
#                     Choose Plan
#                   </Button>
#                 </div>
#               </div>
#             </div>
#           </TabsContent>
#         </Tabs>
#       </div>
#     </ThemeProvider>
#   );
# };
#
# export default PricingComponent_7d278b55_ab8b_4d69_9de4_ab792abecc5d;

# %%
#! Validation currently not working
# codeBody = {"tsx":updatedComponentCode}
# validation_response = re.post(F"{API_ENDPOINT}/api/py/validate_code", json=codeBody)
# fixedCode = validation_response.json()
# print(fixedCode)
