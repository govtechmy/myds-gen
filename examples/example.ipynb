# %% [markdown]
# Usage of myds_gen module

# %%
# import module
import os
os.chdir("..")
from src.myds_gen import GenerateComponent

# %% [markdown]
# ## Generating a new component

# %%
component_description = (
    "a pricing component for Saas"  # provide a description of desired component
)
pricing_component = GenerateComponent(
    component_description
)  # initialization and prompt checking (whether a valid prompt is passed)
pricing_component.component_generation_new()  # generation of the component
# Out:
# 100%|██████████| 5/5 [00:45<00:00,  9.12s/it]
# Component is saved as: output/PricingComponent_ff7d015c-5287-44df-aeb5-22c2bebabe1b.tsx

# %%
print(pricing_component.component_string)  # the generated tsx code
# Out:
# import {
#   Tabs,
#   TabsList,
#   TabsTrigger,
#   TabsContent,
# } from "@govtechmy/myds-react/tabs";
# import {
#   Table,
#   TableBody,
#   TableCell,
#   TableHead,
#   TableHeader,
#   TableRow,
# } from "@govtechmy/myds-react/table";
# import { Button } from "@govtechmy/myds-react/button";
# import { Tag } from "@govtechmy/myds-react/tag";
# import { CheckIcon } from "@govtechmy/myds-react/icon";
# import React from 'react';
#
# const PricingPlans_c991c99b_e8eb_4146_8193_4cbbdbc44236 = () => {
#   return (
#     <div className="bg-gray-50 dark:bg-black py-12 px-4 sm:px-6 lg:px-8">
#       <div className="max-w-7xl mx-auto">
#         <div className="text-center">
#           <h2 className="text-3xl font-semibold text-gray-900 dark:text-white">
#             Pricing Plans
#           </h2>
#         </div>
#         <div className="mt-8">
#           <Tabs defaultValue="monthly" variant="pill" size="medium">
#             <TabsList className="justify-center">
# ...

# %% [markdown]
# ## Updating an existing component

# %%
update_description = "cards should be horizontal to each other"  # provide a description of desired update
pricing_component.component_iteration(
    update_description
)  # initiates and runs the update iteration
# Out:
# Component `PricingComponent_ff7d015c-5287-44df-aeb5-22c2bebabe1b is updated at: output/PricingComponent_ff7d015c-5287-44df-aeb5-22c2bebabe1b.tsx

# %%
print(pricing_component.component_string)  # the updated tsx code
# Out:
# import {
#   Tabs,
#   TabsList,
#   TabsTrigger,
#   TabsContent,
# } from "@govtechmy/myds-react/tabs";
# import {
#   Table,
#   TableBody,
#   TableCell,
#   TableHead,
#   TableHeader,
#   TableRow,
# } from "@govtechmy/myds-react/table";
# import { Button } from "@govtechmy/myds-react/button";
# import { Tag } from "@govtechmy/myds-react/tag";
# import { CheckIcon } from "@govtechmy/myds-react/icon";
# import React from 'react';
# import { ThemeProvider } from "@govtechmy/myds-react/hooks";
# import { ThemeSwitch } from "@govtechmy/myds-react/theme-switch";
#
# const PricingPlans_c991c99b_e8eb_4146_8193_4cbbdbc44236 = () => {
#   return (
#     <ThemeProvider>
#       <div className="bg-gray-50 dark:bg-black py-12 px-4 sm:px-6 lg:px-8">
#         <div className="max-w-7xl mx-auto">
#           <div className="flex justify-between items-center">
#             <h2 className="text-3xl font-semibold text-gray-900 dark:text-white">
#               Pricing Plans
#             </h2>
# ...
